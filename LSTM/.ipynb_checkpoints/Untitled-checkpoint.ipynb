# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import datetime as dt
import os
import numpy as np
from datetime import datetime

# %%
#Read data
df = pd.read_csv("../data/taxi.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10320 entries, 0 to 10319
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10320 non-null  int64
#  1   timestamp   10320 non-null  object
#  2   value       10320 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 242.0+ KB

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0           timestamp  value
# 0           0 2014-07-01 00:00:00  10844
# 1           1 2014-07-01 00:30:00   8127
# 2           2 2014-07-01 01:00:00   6210
# 3           3 2014-07-01 01:30:00   4656
# 4           4 2014-07-01 02:00:00   3820
# 5           5 2014-07-01 02:30:00   2873
# 6           6 2014-07-01 03:00:00   2369
# 7           7 2014-07-01 03:30:00   2064
# 8           8 2014-07-01 04:00:00   2221
# 9           9 2014-07-01 04:30:00   2158

# %%
df = df[['timestamp','value']]

# %%
plt.figure(figsize = (18,19))
plt.plot(df['timestamp'],df['value'])
#plt.xticks(range(0,df.shape[0],500),df['timestamp'].iloc[::100], rotation = 50)
plt.xlabel('Date')
plt.ylabel('Value')
plt.show()

# %%
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),df['value'])
plt.xticks(range(0,df.shape[0],500),df['value'].loc[::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Value',fontsize=18)
plt.axis([0, 1000, 0, 50000])
plt.show()

# %%
plt.figure(figsize=(100,10))
plt.plot(df['timestamp'],df['value'])

# %%
 def df_to_windowed_df(df, first_date_str, last_date_str, n=3):
        import pdb; pdb.set_trace()
        first_date = datetime.striptime(first_date_str)
        last_date = datetime.striptime(last_date_str)
# Out:
#   Cell In[23], line 1
#     def df_to_windowed_df(df, first_date_str, last_date_str, n=3):
#                                                                   ^
# IndentationError: expected an indented block

# %%
df_to_windowed_df(df,'2014-07-01 12:00:00','2014-07-01 16:00:00')
